# %% [markdown]
# # Knox Design Analysis Notebook
#
# Spring 2026
#
# EC552 - Computational Synthetic Biology for Engineers

# %% [markdown]
# Team Members Names: Varsha Athreya & Melissa Regalado

# %% [markdown]
# # Notes From James

# %% [markdown]
# Depending on number of rules, the rule evaluation algorithm can take 10-30 minutes to run. Rule Evaluations are saved in Neo4j, so you do not
# need to rerun the rule evaluation algorithm, call getRuleEvaluation with the name of the evaluation (only 2-5 seconds to retrieve).
#
# Run rule evaluations with:
# - ruleEvaluateByGroup
# - ruleEvaluateByDesigns
#
#
# Get rule evaluations with
# - getRuleEvaluation
#
#
# Delete rule evaluations with
# - deleteRuleEvaluation
#
#
# This notebook is to serve as a starting point for doing your analysis.
#
# Feel free to change this notebook in any way you see fit.

# %% [markdown]
# # Imports

# %%
import requests
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from sklearn import tree
from sklearn.model_selection import train_test_split

print("imports worked")
# Out:
# imports worked

# %% [markdown]
# # Knox Request Functions

# %%
import requests
import pandas as pd
import json

url = 'http://localhost:8080'

def ruleEvaluateByGroup(evalName, groupID, ruleGroupID, labelingMethod="sign"):
    """
    API Request to Knox to run Rule Evaluation Algorithm.

    Returns:
    metrics (list of pandas DataFrames): purity_metrics, designToRule
    """
    response = requests.post(
        url + '/rule/evaluate?' +
        "evaluationName=" + evalName + '&' +
        "designGroupID=" + groupID + '&' +
        "rulesGroupID=" + ruleGroupID + '&' +
        "labelingMethod=" + labelingMethod
    )

    print("Status code:", response.status_code)
    print("Response text:", response.text)

    return processRuleEval(response)


def ruleEvaluateByDesigns(evalName, designIDs, ruleGroupID, designScores, labelingMethod="sign"):
    designSpaceIDs = listToStringList(designIDs)
    designScoresStr = listToStringList(designScores)

    response = requests.post(
        url + '/rule/evaluate?' +
        "evaluationName=" + evalName + '&' +
        "designSpaceIDs=" + designSpaceIDs + '&' +
        "rulesGroupID=" + ruleGroupID + '&' +
        "designScores=" + designScoresStr + '&' +
        "labelingMethod=" + labelingMethod
    )

    return processRuleEval(response)


def getRuleEvaluation(evalName):
    response = requests.get(url + '/rule/getEvaluation?' + "evaluationName=" + evalName)
    return processRuleEval(response)


def deleteRuleEvaluation(evalName):
    response = requests.delete(url + '/rule?' + "evaluationName=" + evalName)

    if not response.text:
        return f'"{evalName}" Successfully Deleted'
    else:
        return response.text


def processRuleEval(response):
    json_data = json.loads(response.text)

    print("Parsed JSON response:")
    print(json_data)

    if "evaluationResults" not in json_data:
        print("Missing 'evaluationResults' in response.")
        return json_data

    if "designToRule" not in json_data:
        print("Missing 'designToRule' in response.")
        return json_data

    purity_metrics_df = pd.DataFrame(json_data["evaluationResults"]).T
    print("purity_metrics_df columns:", purity_metrics_df.columns.tolist())

    designToRule_df = pd.DataFrame(
        json_data["designToRule"],
        index=json_data["designToRule"]["designIDs"]
    )
    cols = designToRule_df.columns.to_list()
    cols.remove("labels")
    cols.remove("scores")
    cols.remove("designIDs")
    cols = ["labels", "scores"] + cols
    designToRule_df = designToRule_df[cols]

    if "scores" in designToRule_df.columns:
        designToRule_df = designToRule_df.sort_values("scores")

    return purity_metrics_df, designToRule_df


def listToStringList(list_input):
    return ",".join(list_input)

# %% [markdown]
# # Decision Tree Functions

# %%
def exampleTree(X, y, **kwargs):
    # Mess around with different parameters
    
    dt_clf = tree.DecisionTreeClassifier(
        splitter=kwargs.get('splitter', 'best'),
        max_depth=kwargs.get('max_depth', None),
        min_samples_split=kwargs.get('min_samples_split', 400),
        min_samples_leaf=kwargs.get('min_samples_leaf', 200),
        max_features=kwargs.get('max_features', None),
        max_leaf_nodes=kwargs.get('max_leaf_nodes', None)
    )
    
    dt_clf = dt_clf.fit(X, y)

    return dt_clf

## Build more Trees, multiclassification and regression

# %% [markdown]
# # Design Analysis

# %% [markdown]
# ### Run RuleEvaluation

# %%
#deleteRuleEvaluation('test')

# %%
# Use this for (gnn_predicted_scores.csv) designs already have the attached scores

evalName = 'ml_rules_eval_1'
groupID = 'ml_designs_3996'
ruleGroupID = "gg_rules"

labelingMethod = 'median'

purity_metrics_df, designToRule_df = ruleEvaluateByGroup(evalName=evalName, groupID=groupID, ruleGroupID=ruleGroupID, labelingMethod=labelingMethod)

# %%
# Use this for extra credit 1 (true_scores.csv & transformer_predicted_scores.csv) attach new scores to the designs

evalName = "test"
designIDs = [f'outputPrefix_design_{i}' for i in range(1, 3997)]
designScores = [str(j) for j in pd.read_csv(r"C:\Path\to\transformer_predicted_scores.csv")["weight"].to_list()]
ruleGroupID = 'ruleGroup'

labelingMethod = 'median'

purity_metrics_df, designToRule_df = ruleEvaluateByDesigns(evalName, designIDs, ruleGroupID, designScores, labelingMethod)

# %% [markdown]
# ### View DataFrames

# %%
purity_metrics_df
# Out:
#                               Impact poorPerfection poornessPercent  \
# rule_A1_B2_Rule_B                 -8           True             100
# rule_PA1_B1_Rule_I                -3           True             100
# rule_B1_P2_Rule_F                -13          False              68
# rule_B2andP2_PP2andPS1_Rule_O     10          False              83
# rule_A1_B2_Rule_A                -18          False              80
# ...                              ...            ...             ...
# rule_A1_Rule_M                    18          False              19
# rule_P2_S1_Rule_A                 51          False              36
# rule_S1_B1_Rule_T                 -4          False              56
# rule_A1andH2_PA2andPB1_Rule_O    -12          False              96
# rule_P2_S1_Rule_B                  3          False              96
#
#                               goodDesignsElim totalPerfection numCorrect  \
# rule_A1_B2_Rule_B                         168           False       1830
# rule_PA1_B1_Rule_I                         60           False       1938
# rule_B1_P2_Rule_F                         888           False       1734
# rule_B2andP2_PP2andPS1_Rule_O             118           False       2202
# rule_A1_B2_Rule_A                         758           False       1634
# ...                                       ...             ...        ...
# rule_A1_Rule_M                           1240           False       2362
# rule_P2_S1_Rule_A                         241           False       3028
# rule_S1_B1_Rule_T                         966           False       1902
# rule_A1andH2_PA2andPB1_Rule_O             304           False       1756
# rule_P2_S1_Rule_B                          12           False       2058
#
#                               goodPerfection goodnessPercent numIncorrect  \
# rule_A1_B2_Rule_B                      False              91         2166
# rule_PA1_B1_Rule_I                     False              96         2058
# rule_B1_P2_Rule_F                      False              55         2262
# rule_B2andP2_PP2andPS1_Rule_O          False              94         1794
# rule_A1_B2_Rule_A                      False              62         2362
# ...                                      ...             ...          ...
# rule_A1_Rule_M                         False              37         1634
# rule_P2_S1_Rule_A                      False              87          968
# rule_S1_B1_Rule_T                      False              51         2094
# rule_A1andH2_PA2andPB1_Rule_O          False              84         2240
# rule_P2_S1_Rule_B                      False              99         1938
#
#                               poorEliminationPercent poorDesignsElim
# rule_A1_B2_Rule_B                                  0               0
# rule_PA1_B1_Rule_I                                 0               0
# rule_B1_P2_Rule_F                                 41             624
# rule_B2andP2_PP2andPS1_Rule_O                     73             322
# rule_A1_B2_Rule_A                                 34             394
# ...                                              ...             ...
# rule_A1_Rule_M                                    56            1604
# rule_P2_S1_Rule_A                                 84            1271
# rule_S1_B1_Rule_T                                 47             870
# rule_A1andH2_PA2andPB1_Rule_O                     16              62
# rule_P2_S1_Rule_B                                 85              72
#
# [276 rows x 11 columns]

# %%
designToRule_df
# Out:
#                 labels    scores  rule_A1_B2_Rule_B  rule_PA1_B1_Rule_I  \
# ml_design_181        0 -0.955420                  0                   0
# ml_design_284        0 -0.948819                  0                   0
# ml_design_277        0 -0.944792                  0                   0
# ml_design_122        0 -0.935556                  0                   0
# ml_design_170        0 -0.930752                  0                   0
# ...                ...       ...                ...                 ...
# ml_design_3936       1  3.407576                  0                   0
# ml_design_3935       1  3.427389                  0                   0
# ml_design_3929       1  3.437174                  0                   0
# ml_design_3927       1  3.447912                  0                   0
# ml_design_3930       1  3.462357                  0                   0
#
#                 rule_B1_P2_Rule_F  rule_B2andP2_PP2andPS1_Rule_O  \
# ml_design_181                   0                              0
# ml_design_284                   0                              0
# ml_design_277                   0                              0
# ml_design_122                   1                              0
# ml_design_170                   1                              0
# ...                           ...                            ...
# ml_design_3936                  0                              0
# ml_design_3935                  0                              0
# ml_design_3929                  0                              0
# ml_design_3927                  0                              0
# ml_design_3930                  0                              0
#
#                 rule_A1_B2_Rule_A  rule_A1_B2_Rule_F  \
# ml_design_181                   1                  1
# ml_design_284                   1                  1
# ml_design_277                   0                  0
# ml_design_122                   0                  0
# ml_design_170                   0                  0
# ...                           ...                ...
# ml_design_3936                  0                  0
# ml_design_3935                  0                  0
# ml_design_3929                  0                  0
# ml_design_3927                  0                  0
# ml_design_3930                  0                  0
#
#                 rule_H1andS1_PB1andPB2_Rule_O  rule_H1_Rule_M  ...  \
# ml_design_181                               0               1  ...
# ml_design_284                               0               1  ...
# ml_design_277                               1               1  ...
# ml_design_122                               1               1  ...
# ml_design_170                               1               1  ...
# ...                                       ...             ...  ...
# ml_design_3936                              0               1  ...
# ml_design_3935                              0               1  ...
# ml_design_3929                              0               1  ...
# ml_design_3927                              0               1  ...
# ml_design_3930                              0               1  ...
#
#                 rule_H1_P1_Rule_A  rule_H1_P1_Rule_F  rule_A1_Rule_R  \
# ml_design_181                   0                  0               1
# ml_design_284                   0                  0               1
# ml_design_277                   0                  0               0
# ml_design_122                   0                  0               0
# ml_design_170                   0                  0               0
# ...                           ...                ...             ...
# ml_design_3936                  0                  0               0
# ml_design_3935                  0                  0               0
# ml_design_3929                  0                  0               0
# ml_design_3927                  0                  0               0
# ml_design_3930                  0                  0               0
#
#                 rule_B2_P2_Rule_A  rule_A1andS1_PH1andPP1_Rule_O  \
# ml_design_181                   0                              0
# ml_design_284                   0                              0
# ml_design_277                   1                              0
# ml_design_122                   1                              0
# ml_design_170                   1                              0
# ...                           ...                            ...
# ml_design_3936                  0                              1
# ml_design_3935                  0                              1
# ml_design_3929                  0                              1
# ml_design_3927                  0                              1
# ml_design_3930                  0                              1
#
#                 rule_A1_Rule_M  rule_P2_S1_Rule_A  rule_S1_B1_Rule_T  \
# ml_design_181                0                  0                  1
# ml_design_284                0                  0                  1
# ml_design_277                1                  0                  1
# ml_design_122                1                  0                  0
# ml_design_170                1                  0                  0
# ...                        ...                ...                ...
# ml_design_3936               1                  1                  1
# ml_design_3935               1                  1                  1
# ml_design_3929               1                  1                  1
# ml_design_3927               1                  1                  1
# ml_design_3930               1                  1                  1
#
#                 rule_A1andH2_PA2andPB1_Rule_O  rule_P2_S1_Rule_B
# ml_design_181                               1                  0
# ml_design_284                               0                  0
# ml_design_277                               0                  0
# ml_design_122                               0                  0
# ml_design_170                               0                  0
# ...                                       ...                ...
# ml_design_3936                              0                  0
# ml_design_3935                              0                  1
# ml_design_3929                              0                  0
# ml_design_3927                              0                  0
# ml_design_3930                              0                  0
#
# [3996 rows x 278 columns]

# %%
#saving files to csvs 

purity_metrics_df.to_csv("purity_metrics.csv", index=True)
designToRule_df.to_csv("design_to_rule.csv", index=True)

# %% [markdown]
# ## Extract Features and Labels from designToRule_df

# %%
feature_names = designToRule_df.columns.to_list()[2:]
X = designToRule_df.iloc[:, 2:].to_numpy(dtype=int)
y_labels = designToRule_df["labels"].to_numpy(dtype=int)
y_scores = designToRule_df["scores"].to_numpy(dtype=float)

# %% [markdown]
# ## Train - Test Split

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# Features
feature_cols = [c for c in designToRule_df.columns if c not in ["labels", "scores"]]
X = designToRule_df[feature_cols]

# Targets
y_binary = designToRule_df["labels"]          # binary classification
y_reg = designToRule_df["scores"]             # regression

# Multi-class target using score quantiles
y_multi = pd.qcut(
    designToRule_df["scores"],
    q=4,
    labels=["awful", "poor", "good", "great"],
    duplicates="drop"
)

# 70/30 train-test splits
X_train_bin, X_test_bin, y_train_bin, y_test_bin = train_test_split(
    X, y_binary, test_size=0.30, random_state=42
)

X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(
    X, y_reg, test_size=0.30, random_state=42
)

X_train_multi, X_test_multi, y_train_multi, y_test_multi = train_test_split(
    X, y_multi, test_size=0.30, random_state=42
)

# %% [markdown]
# ## Build Trees

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error

# Binary Classification Tree
binary_tree = DecisionTreeClassifier(max_depth=5, random_state=42)
binary_tree.fit(X_train_bin, y_train_bin)
y_pred_bin = binary_tree.predict(X_test_bin)
print("Binary Classification Accuracy:", accuracy_score(y_test_bin, y_pred_bin))

# Regression Tree
regression_tree = DecisionTreeRegressor(max_depth=5, random_state=42)
regression_tree.fit(X_train_reg, y_train_reg)
y_pred_reg = regression_tree.predict(X_test_reg)
print("Regression MAE:", mean_absolute_error(y_test_reg, y_pred_reg))
print("Regression MSE:", mean_squared_error(y_test_reg, y_pred_reg))

# Multi-Classification Tree
multi_tree = DecisionTreeClassifier(max_depth=5, random_state=42)
multi_tree.fit(X_train_multi, y_train_multi)
y_pred_multi = multi_tree.predict(X_test_multi)
print("Multi-Classification Accuracy:", accuracy_score(y_test_multi, y_pred_multi))

# %% [markdown]
# ## Plot Trees

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Binary Classification Tree
plt.figure(figsize=(24, 12))
plot_tree(
    binary_tree,
    feature_names=feature_cols,
    class_names=["0", "1"],
    filled=True,
    fontsize=8
)
plt.title("Binary Classification Tree")
plt.show()

# Regression Tree
plt.figure(figsize=(24, 12))
plot_tree(
    regression_tree,
    feature_names=feature_cols,
    filled=True,
    fontsize=8
)
plt.title("Regression Tree")
plt.show()

# Multi-Classification Tree
plt.figure(figsize=(24, 12))
plot_tree(
    multi_tree,
    feature_names=feature_cols,
    class_names=[str(c) for c in y_multi.cat.categories],
    filled=True,
    fontsize=8
)
plt.title("Multi-Classification (Binned) Tree")
plt.show()

# %% [markdown]
# ## Save Trees

# %%
# Save Binary Classification Tree
plt.figure(figsize=(24, 12))
plot_tree(
    binary_tree,
    feature_names=feature_cols,
    class_names=["0", "1"],
    filled=True,
    fontsize=8
)
plt.title("Binary Classification Tree")
plt.savefig("binary_classification_tree.png", bbox_inches="tight")
plt.show()

# Save Regression Tree
plt.figure(figsize=(24, 12))
plot_tree(
    regression_tree,
    feature_names=feature_cols,
    filled=True,
    fontsize=8
)
plt.title("Regression Tree")
plt.savefig("regression_tree.png", bbox_inches="tight")
plt.show()

# Save Multi-Classification Tree
plt.figure(figsize=(24, 12))
plot_tree(
    multi_tree,
    feature_names=feature_cols,
    class_names=[str(c) for c in y_multi.cat.categories],
    filled=True,
    fontsize=8
)
plt.title("Multi-Classification (Binned) Tree")
plt.savefig("multi_classification_tree.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Save Purity Metrics and DesignToRule DF to CSV

# %%
purity_metrics_df.to_csv("purity_metrics_df.csv", index=True)
designToRule_df.to_csv("designToRule_df.csv", index=True)

print("Saved purity_metrics_df.csv")
print("Saved designToRule_df.csv")

# %% [markdown]
# # Deliverables

# %% [markdown]
# **1. How many rules did you use? Why did you choose those rules?** <br>
# We originally maunally wrote about 500 rules. However, only 276 of them ended up being unique due to duplicates in the rules we manually generated. To choose rules we tried many combination of the cds and promotor parts from the parts library. <br>
# **3. What are we learning from each type of tree?** <br>
# From the regression tree, we are trying to predict the scores. From the binary decision tree, we are learning which rules best separate designs. In other words, we see which rules best split the designs into following and not following that rule. FThe multi-classification tree is similar to the regression tree except instead of predicting continuous scores, we predict a classification of the scores. We turn the continuous label into discrete categories (swful, poor, good, great) and predict those instead. Going from binary, to multi-classification, and to regression, we are getting more and more fine grained information of how well designs follow rules. <br>
# **5. What are some interesting insights you noticed about some of the rules?** <br>
# The binary classification tree does pretty well in producing accurate and pure leaves, revealing that determining whether a design follows a rule is somewhat of an easy problem. Also, in all 3 trees, rule R seems harder to predict using decision trees because leaves with Rule R are relatively impure in all of them. Rule R is do not repeat A which has much more possible combinations then the some of the other rules, so it is possible that there are not enough designs where the model is able to effectively learn R. <br>
# **6. If you were to experimentally validate five of these rules, which would you choose?
# Why?** <br>
# Experiementally validating rules would help us understand whether rules are actually biologically applicable. Since promotors are the start of where DNA transcription would occur. I would test rules starting with a promotor sequence. For example, I would test starts with Pl1 and starts with PA1. Then I would test ending with a CDS. A CDS is the part of the DNA sequence that is translated into protein. I would test a rule like ends with A1 to see whether CDS should be at the end. To test promotor and CDS together, I would use the followed by rule, for example where a promotor is followed by a CDS and vice versa to see which design is better. I predict a promotor followed by a CDS would be a better design. Two specific rules coule be Pln1 followed by A1 and A1 followed by Pln1. These are all the five rules I would experimentally validate.
